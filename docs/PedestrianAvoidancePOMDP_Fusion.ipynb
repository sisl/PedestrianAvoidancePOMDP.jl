# %% [markdown]
# If you want to be in the `PedestrianAvoidancePOMDP` environment, run the following cell. If the package has been added to the main julia environment, it is not necessary.

# %%
] activate ../

# %%
using Revise
using AutomotiveDrivingModels
using AutoViz
using AutomotiveSensors
using AutomotivePOMDPs
using GridInterpolations

using PedestrianAvoidancePOMDP
using POMDPPolicies

using JLD2
using FileIO
using Reel
using Random
using POMDPs
using POMDPModelTools
using LinearAlgebra

# %%
policy = load("../policy/policy.jld2")["policy"]; # need to be updated

# %%
using EmergencyBrakingSystem

pomdp = SingleOCFPOMDP()
updater = SingleOCFUpdater(pomdp)

parameters = CrosswalkParams()
parameters.roadway_length = 400.0
parameters.obstacles_visible = false

obstacle_offset = -2
obstacle_1 = ConvexPolygon([VecE2(34, obstacle_offset), VecE2(34, obstacle_offset-3), VecE2(46.5, obstacle_offset-3), VecE2(46.5, obstacle_offset)],4)
obstacle_2 = ConvexPolygon([VecE2(34, +4.5), VecE2(34, +7.5), VecE2(46.5, +7.5), VecE2(46.5, +4.5)],4)
parameters.obstacles = [obstacle_1, obstacle_2]
#parameters.obstacles = [obstacle_2]

env = CrosswalkEnv(parameters)
pomdp.env = env


ego_id = 1
ped_id = 2
ped2_id = 3


ego_v = 11.11
ped_v = 5.4/3.6
hitpoint = 50             # 50: middle, 100: left corner, 0: right corner
ped_theta = π/2


# fix values
ped_x = 50.0
ped_y_start = -7.0
ego_y = 0.0


ped_y_offset_hitpoint = VehicleDef().width * hitpoint / 100 - VehicleDef().width/2
ped_y_end = ped_y_offset_hitpoint
ped_t_collision = (ped_y_end - ped_y_start) / ped_v; 
ego_x = ped_x - ego_v * ped_t_collision - VehicleDef().length/2;

if ( false )
    ego_v = 0.0
    ego_x = 20
    ped_x = 30
    ped_y_start = -2.0
    ped_v = 0.0
end

ped_y_start = -1.
ped_v = 0.0
ego_y = 0.0
# Car definition
ego_initial_state = VehicleState(VecSE2(ego_x, ego_y, 0.), env.roadway.segments[1].lanes[1], env.roadway, ego_v)
ego = Vehicle(ego_initial_state, VehicleDef(), 1)

# Pedestrian definition 
ped_initial_state = VehicleState(VecSE2(ped_x,ped_y_start,ped_theta), env.crosswalk, env.roadway, ped_v)
ped = Vehicle(ped_initial_state, AutomotivePOMDPs.PEDESTRIAN_DEF, 2)

ped2_v = 0.0
ped2 = Vehicle(VehicleState(VecSE2(54., 5., 0.78), env.crosswalk, env.roadway, ped2_v), AutomotivePOMDPs.PEDESTRIAN_DEF, ped2_id)


scene = Scene()
push!(scene, ego)
push!(scene, ped)
push!(scene, ped2)



cam = FitToContentCamera(0.);
timestep = 0.05
timestep_pomdp = 0.2 

pos_noise = 0.00
vel_noise = 0.00
false_positive_rate = 0.00
false_negative_rate = 0.00
rng = MersenneTwister(1);
sensor = AutomotiveSensors.GaussianSensor(AutomotiveSensors.LinearNoise(10, pos_noise, 0.00), 
                 AutomotiveSensors.LinearNoise(10, vel_noise, 0.00), false_positive_rate, false_negative_rate, rng) 


# define a model for each entities present in the scene
models = Dict{Int, DriverModel}()

emergency_braking_system = EmergencyBrakingSystem.EmergencySystem(a=LatLonAccel(0.0, 0.0),
        env=env,
        sensor=sensor, 
        obstacles=env.obstacles, 
        SAFETY_DISTANCE_LON=1.0,
        AX_MAX=-10.0,
        THRESHOLD_COLLISION_RATE = 0.6,
        THRESHOLD_TIME_TO_REACT = 0.99,    
        timestep=timestep)

pomdp.desired_velocity = ego_v
pomdp.ΔT = timestep
frenet_pedestrian_pomdp = FrenetPedestrianPOMDP(a=LatLonAccel(0.0, 0.0),
    env=env,
    sensor=sensor,
    obstacles=env.obstacles,
    timestep=timestep_pomdp,
    pomdp=pomdp,
    policy=policy,
    updater=updater,
    ego_vehicle=ego,
    desired_velocity=ego_v,
    b=PedestrianAvoidancePOMDP.initBeliefAbsentPedestrian(pomdp, ego_y, ego_v)
)

pedestrian_system = PedestrianSystem(
    frenet_pedestrian_pomdp=frenet_pedestrian_pomdp, 
    emergency_braking_system=emergency_braking_system,
    update_tick_high_level_planner = timestep_pomdp / timestep,
    b=PedestrianAvoidancePOMDP.initBeliefAbsentPedestrian(pomdp, ego_y, ego_v),
    timestep=timestep
)

models[ped_id] = ConstantPedestrian(v_desired=ped.state.v, dawdling_amp=0.0001) # dumb model
models[ped2_id] = ConstantPedestrian(v_desired=ped2.state.v, dawdling_amp=0.0001) # dumb model



scene = Scene()
push!(scene, ego)
push!(scene, ped)
push!(scene, ped2)



cam = FitToContentCamera(0.);


pos_noise = 0.001
vel_noise = 0.000
false_positive_rate = 0.00
false_negative_rate = 0.00
rng = MersenneTwister(1);
sensor = AutomotiveSensors.GaussianSensor(AutomotiveSensors.LinearNoise(10, pos_noise, 0.00), 
                 AutomotiveSensors.LinearNoise(10, vel_noise, 0.00), false_positive_rate, false_negative_rate, rng) 


# define a model for each entities present in the scene
models = Dict{Int, DriverModel}()

pomdp.desired_velocity = ego_v
pomdp.ΔT = timestep
models[ego_id] = pedestrian_system

models[ped_id] = ConstantPedestrian(v_desired=ped.state.v, dawdling_amp=0.001) # dumb model
models[ped2_id] = ConstantPedestrian(v_desired=ped2.state.v, dawdling_amp=0.001) # dumb model



nticks = 200
rec = SceneRecord(nticks+1, timestep)

risk = Float64[]
sensor_observations = [Vehicle[]]
belief = Dict{Int64, SingleOCFBelief}[]
ego_vehicle = Vehicle[]
action_pomdp = SingleOCFAction[]
prediction = Vector{Array{Float64}}()
obs_callback = (ObservationPedestrianAvoidanceCallback(risk,sensor_observations, belief, ego_vehicle, action_pomdp, prediction),)

@elapsed begin
simulate!(rec, scene, env.roadway, models, nticks, obs_callback)
end
# Out:
# model.t_current: 0.0
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 0.0
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.05
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.1
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.15000000000000002
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.2
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 0.2
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.25
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.3
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.35
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.39999999999999997
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 0.39999999999999997
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.44999999999999996
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.49999999999999994
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.5499999999999999
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.6
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 0.6
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.65
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.7000000000000001
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.7500000000000001
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.8000000000000002
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 0.8000000000000002
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.8500000000000002
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.9000000000000002
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 0.9500000000000003
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.0000000000000002
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 1.0000000000000002
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.0500000000000003
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.1000000000000003
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.1500000000000004
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.2000000000000004
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 1.2000000000000004
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.2500000000000004
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.3000000000000005
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.3500000000000005
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.4000000000000006
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 1.4000000000000006
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.4500000000000006
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.5000000000000007
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.5500000000000007
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.6000000000000008
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 1.6000000000000008
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.6500000000000008
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.7000000000000008
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 3.0116711671167113 ttc_std: 0.0816325157928002Risk: 0.3272032169637548 ttc_min: 2.848406135531111
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.7500000000000009
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 2.961671167116711 ttc_std: 0.09472344924440611Risk: 0.3361948963913983 ttc_min: 2.772224268627899
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.800000000000001
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.9116711671167113 ttc_std: 0.06131511736637799Risk: 0.3341677922125135 ttc_min: 2.7890409323839553
# --------------------------POMDP high level planner----------------------- t: 1.800000000000001
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.850000000000001
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 2.8616711671167114 ttc_std: 0.0923008546345749Risk: 0.3481447401497145 ttc_min: 2.6770694578475616
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.900000000000001
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.8116711671167116 ttc_std: 0.07752004648333918Risk: 0.3508231383099607 ttc_min: 2.656631074150033
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 1.950000000000001
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.7616711671167113 ttc_std: 0.07649192915597383Risk: 0.3572707421159263 ttc_min: 2.6086873088047637
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.000000000000001
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 2.7116711671167115 ttc_std: 0.08890922218081095Risk: 0.36782234515654605 ttc_min: 2.5338527227550895
# --------------------------POMDP high level planner----------------------- t: 2.000000000000001
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.0500000000000007
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 2.6616711671167117 ttc_std: 0.08769792487589533Risk: 0.3748609996067792 ttc_min: 2.486275317364921
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.1000000000000005
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.6116711671167114 ttc_std: 0.07340757717387823Risk: 0.3781184969575904 ttc_min: 2.464856012768955
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.1500000000000004
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.561671167116712 ttc_std: 0.055755456465281426Risk: 0.38038640500053916 ttc_min: 2.4501602541861494
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.2
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.5116711671167122 ttc_std: 0.05496121919369619Risk: 0.38805377082812853 ttc_min: 2.40174872872932
# --------------------------POMDP high level planner----------------------- t: 2.2
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.25
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.4616711671167124 ttc_std: 0.05416698192211108Risk: 0.3960365941051927 ttc_min: 2.35333720327249
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.3
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.411671167116712 ttc_std: 0.05337274465052586Risk: 0.40435475197114584 ttc_min: 2.3049256778156604
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.3499999999999996
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.3616711671167128 ttc_std: 0.068266990537052Risk: 0.41885401790558624 ttc_min: 2.2251371860426086
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.3999999999999995
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.311671167116713 ttc_std: 0.06723887320968666Risk: 0.42807756164657207 ttc_min: 2.1771934206973396
# --------------------------POMDP high level planner----------------------- t: 2.3999999999999995
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.4499999999999993
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.2616711671167127 ttc_std: 0.07723116499595273Risk: 0.4422948662443726 ttc_min: 2.107208837124807
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.499999999999999
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.211671167116713 ttc_std: 0.0501957955641849Risk: 0.4414420815532118 ttc_min: 2.111279575988343
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.549999999999999
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 2.161671167116713 ttc_std: 0.06415452122759094Risk: 0.4583579282122295 ttc_min: 2.033362124661531
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.5999999999999988
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 2.1116711671167137 ttc_std: 0.04860732102101464Risk: 0.46265960032596043 ttc_min: 2.014456525074684
# --------------------------POMDP high level planner----------------------- t: 2.5999999999999988
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.6499999999999986
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 2.0616711671167134 ttc_std: 0.06953068441859249Risk: 0.4847617293946464 ttc_min: 1.9226097982795285
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.6999999999999984
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 2.0116711671167136 ttc_std: 0.06837951414676151Risk: 0.4970940405506476 ttc_min: 1.8749121388231906
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.7499999999999982
# -> emergency braking system
#  collision_rate: 0.8 ttc_m: 1.9616711671167137 ttc_std: 0.06329665682895295Risk: 0.5078845287181694 ttc_min: 1.835077853458808
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.799999999999998
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.9116711671167135 ttc_std: 0.059013934590764816Risk: 0.519617056433679 ttc_min: 1.793643297935184
# --------------------------POMDP high level planner----------------------- t: 2.799999999999998
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.849999999999998
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.8616711671167134 ttc_std: 0.04463613466308848Risk: 0.5258453116433962 ttc_min: 1.7723988977905365
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.8999999999999977
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.8116711671167138 ttc_std: 0.056957699936034355Risk: 0.5489645028729124 ttc_min: 1.697755767244645
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.9499999999999975
# -> emergency braking system
#  collision_rate: 0.9 ttc_m: 1.761671167116714 ttc_std: 0.05538446867368013Risk: 0.5645444254414065 ttc_min: 1.6509022297693536
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 2.9999999999999973
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.7116711671167142 ttc_std: 0.04225342284833295Risk: 0.5727802893021283 ttc_min: 1.6271643214200482
# --------------------------POMDP high level planner----------------------- t: 2.9999999999999973
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.049999999999997
# -> emergency braking system
#  collision_rate: 0.9 ttc_m: 1.6616711671167144 ttc_std: 0.05334827497244187Risk: 0.5993716170494159 ttc_min: 1.5549746171718306
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.099999999999997
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.6116711671167145 ttc_std: 0.040664948305162575Risk: 0.609019483906799 ttc_min: 1.5303412705063895
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.149999999999997
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.561671167116715 ttc_std: 0.03987071103357736Risk: 0.6289148685209145 ttc_min: 1.4819297450495603
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.1999999999999966
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.5116711671167145 ttc_std: 0.039076473761992206Risk: 0.6501540322451324 ttc_min: 1.43351821959273
# --------------------------POMDP high level planner----------------------- t: 3.1999999999999966
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.2499999999999964
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.4616711671167149 ttc_std: 0.04976087864447765Risk: 0.6842183713774296 ttc_min: 1.3621494098277596
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.2999999999999963
# -> emergency braking system
#  collision_rate: 0.4 ttc_m: 1.4116711671167144 ttc_std: 0.037487999218821684Risk: 0.6972477140663951 ttc_min: 1.336695168679071
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.349999999999996
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.3616711671167143 ttc_std: 0.0477046439897472Risk: 0.7360307264403388 ttc_min: 1.26626187913722
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.399999999999996
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.311671167116714 ttc_std: 0.04667652666238194Risk: 0.7649953162596036 ttc_min: 1.21831811379195
# --------------------------POMDP high level planner----------------------- t: 3.399999999999996
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.4499999999999957
# -> emergency braking system
#  collision_rate: 0.9 ttc_m: 1.2616711671167138 ttc_std: 0.04520350016748892Risk: 0.7957279640219331 ttc_min: 1.1712641667817358
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.4999999999999956
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 1.2116711671167137 ttc_std: 0.044620292007651406Risk: 0.8303476979305278 ttc_min: 1.122430583101411
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.5499999999999954
# -> emergency braking system
#  collision_rate: 0.9 ttc_m: 1.1616711671167135 ttc_std: 0.04316730646625069Risk: 0.8667125163173962 ttc_min: 1.0753365541842121
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.599999999999995
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 1.1116711671167132 ttc_std: 0.0441078409303809Risk: 0.9106479609437971 ttc_min: 1.0234554852559514
# --------------------------POMDP high level planner----------------------- t: 3.599999999999995
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.649999999999995
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 1.0616711671167127 ttc_std: 0.043042434144622915Risk: 0.9553308117234053 ttc_min: 0.9755862988274668
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.699999999999995
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 1.0116711671167127 ttc_std: 0.038051782824392595Risk: 0.9961948760332601 ttc_min: 0.9355676014679275
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.7499999999999947
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.9616711671167126 ttc_std: 0.03708600153443337Risk: 1.0 ttc_min: 0.8874991640478459
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.7999999999999945
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.9116711671167125 ttc_std: 0.03984621378734901Risk: 1.0 ttc_min: 0.8319787395420144
# --------------------------POMDP high level planner----------------------- t: 3.7999999999999945
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.8499999999999943
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.8616711671167122 ttc_std: 0.03515443895451496Risk: 1.0 ttc_min: 0.7913622892076823
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.899999999999994
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.8116711671167121 ttc_std: 0.03418865766455577Risk: 1.0 ttc_min: 0.7432938517876005
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 3.949999999999994
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 0.7616711671167119 ttc_std: 0.03516161259589123Risk: 1.0 ttc_min: 0.6913479419249294
# a: LatLonAccel( 0.000, -2.500)
# model.t_current: 3.999999999999994
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.7200538613260505 ttc_std: 0.03749805141229329Risk: 1.0 ttc_min: 0.645057758501464
# --------------------------POMDP high level planner----------------------- t: 3.999999999999994
# a: LatLonAccel( 0.000, -5.000)
# model.t_current: 4.049999999999994
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.6862404906070491 ttc_std: 0.039253416886433044Risk: 1.0 ttc_min: 0.607733656834183
# a: LatLonAccel( 0.000, -7.500)
# model.t_current: 4.099999999999993
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 0.6601753539253538 ttc_std: 0.06328617889028931Risk: 1.0 ttc_min: 0.5336029961447751
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.149999999999993
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 0.6423850574712636 ttc_std: 0.04059370312473815Risk: 1.0 ttc_min: 0.5611976512217873
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.199999999999993
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.6253650284900294 ttc_std: 0.045166165296901886Risk: 1.0 ttc_min: 0.5350326978962257
# --------------------------POMDP high level planner----------------------- t: 4.199999999999993
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.249999999999993
# -> emergency braking system
#  collision_rate: 0.5 ttc_m: 0.6092456734386774 ttc_std: 0.04282250054752466Risk: 1.0 ttc_min: 0.5236006723436281
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.299999999999993
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 0.5941885964912288 ttc_std: 0.04836750910870631Risk: 1.0 ttc_min: 0.4974535782738162
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.3499999999999925
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.5803965224766772 ttc_std: 0.04969030747896454Risk: 1.0 ttc_min: 0.4810159075187481
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.399999999999992
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.5681272644927562 ttc_std: 0.051608150360491115Risk: 1.0 ttc_min: 0.464910963771774
# --------------------------POMDP high level planner----------------------- t: 4.399999999999992
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.449999999999992
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 0.5577137998056403 ttc_std: 0.05428129771561327Risk: 1.0 ttc_min: 0.44915120437441375
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.499999999999992
# -> emergency braking system
#  collision_rate: 0.6 ttc_m: 0.5495938155136298 ttc_std: 0.05675272308523257Risk: 1.0 ttc_min: 0.4360883693431647
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.549999999999992
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.544354379977251 ttc_std: 0.06423312057930507Risk: 1.0 ttc_min: 0.41588813881864084
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.599999999999992
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.542801616915428 ttc_std: 0.06801668231435753Risk: 1.0 ttc_min: 0.406768252286713
# --------------------------POMDP high level planner----------------------- t: 4.599999999999992
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.6499999999999915
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.5460733882030224 ttc_std: 0.06755818971651652Risk: 1.0 ttc_min: 0.4109570087699894
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.699999999999991
# -> emergency braking system
#  collision_rate: 0.8 ttc_m: 0.5558295107033725 ttc_std: 0.07760949280399247Risk: 1.0 ttc_min: 0.4006105250953875
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.749999999999991
# -> emergency braking system
#  collision_rate: 0.7 ttc_m: 0.5745898100172788 ttc_std: 0.08156875797096293Risk: 1.0 ttc_min: 0.411452294075353
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.799999999999991
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.6063740079365183 ttc_std: 0.08813789036545538Risk: 1.0 ttc_min: 0.43009822720560753
# --------------------------POMDP high level planner----------------------- t: 4.799999999999991
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.849999999999991
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.6580128205128338 ttc_std: 0.09979492360016899Risk: 1.0 ttc_min: 0.4584229733124958
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.899999999999991
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.7421257062147094 ttc_std: 0.1127541471440166Risk: 1.0 ttc_min: 0.5166174119266762
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.94999999999999
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 0.8849014336917783 ttc_std: 0.14191065657719878Risk: 1.0 ttc_min: 0.6010801205373808
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 4.99999999999999
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 1.1510416666666965 ttc_std: 0.179882446321313Risk: 1.0 ttc_min: 0.7912767740240705
# --------------------------POMDP high level planner----------------------- t: 4.99999999999999
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 5.04999999999999
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 1.7557170542636193 ttc_std: 0.25951217062103754Risk: 1.0 ttc_min: 1.2366927130215442
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 5.09999999999999
# -> emergency braking system
#  collision_rate: 1.0 ttc_m: 4.109490740740882 ttc_std: 0.6199457409280347Risk: 0.933618554164345 ttc_min: 2.8695992588848127
# a: LatLonAccel( 0.000, -10.000)
# model.t_current: 5.14999999999999
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.1999999999999895
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 5.1999999999999895
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.249999999999989
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.299999999999989
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.349999999999989
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.399999999999989
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 5.399999999999989
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.449999999999989
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.4999999999999885
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.549999999999988
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.599999999999988
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 5.599999999999988
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.649999999999988
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.699999999999988
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.749999999999988
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.799999999999987
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 5.799999999999987
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.849999999999987
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.899999999999987
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.949999999999987
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 5.999999999999987
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 5.999999999999987
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.0499999999999865
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.099999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.149999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.199999999999986
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 6.199999999999986
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.249999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.299999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.349999999999985
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.399999999999985
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 6.399999999999985
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.449999999999985
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.499999999999985
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.549999999999985
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.5999999999999845
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 6.5999999999999845
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.649999999999984
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.699999999999984
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.749999999999984
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.799999999999984
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 6.799999999999984
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.849999999999984
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.8999999999999835
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.949999999999983
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 6.999999999999983
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 6.999999999999983
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.049999999999983
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.099999999999983
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.149999999999983
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.199999999999982
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 7.199999999999982
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.249999999999982
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.299999999999982
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.349999999999982
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.399999999999982
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 7.399999999999982
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.4499999999999815
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.499999999999981
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.549999999999981
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.599999999999981
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 7.599999999999981
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.649999999999981
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.699999999999981
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.7499999999999805
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.79999999999998
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 7.79999999999998
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.84999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.89999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.94999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 7.99999999999998
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 7.99999999999998
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.04999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.09999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.14999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.199999999999982
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 8.199999999999982
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.249999999999982
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.299999999999983
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.349999999999984
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.399999999999984
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 8.399999999999984
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.449999999999985
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.499999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.549999999999986
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.599999999999987
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 8.599999999999987
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.649999999999988
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.699999999999989
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.74999999999999
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.79999999999999
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 8.79999999999999
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.84999999999999
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.899999999999991
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.949999999999992
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 8.999999999999993
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 8.999999999999993
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.049999999999994
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.099999999999994
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.149999999999995
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.199999999999996
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 9.199999999999996
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.249999999999996
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.299999999999997
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.349999999999998
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.399999999999999
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 9.399999999999999
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.45
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.5
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.55
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.600000000000001
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 9.600000000000001
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.650000000000002
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.700000000000003
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.750000000000004
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.800000000000004
# -> emergency braking system
# --------------------------POMDP high level planner----------------------- t: 9.800000000000004
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.850000000000005
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.900000000000006
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# model.t_current: 9.950000000000006
# -> emergency braking system
# a: LatLonAccel( 0.000,  0.000)
# 1.045894191

# %%
# Visualize scenario
duration, fps, render_hist = animate_record(rec, timestep, env, sensor, sensor_observations, risk, belief, ego_vehicle, action_pomdp, prediction, CarFollowCamera(2,10.0))
film = roll(render_hist, fps = fps, duration = duration)
#write("file.mp4", film) # Write to a webm video
# Out:
# Frames{MIME{Symbol("image/png")}}("/tmp/tmpICDfuD", 0x00000000000000c9, 20.0, nothing)
